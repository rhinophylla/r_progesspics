# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import itertools
import time
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# set plot style
plt.style.use('ggplot')

# %%
# import data
pp_data = pd.read_csv("../data/pp_data_2018_processed.csv")
pp_duration = pd.read_csv("../data/pp_duration_2018_processed.csv")

# %%
pp_data.head()
# Out:
#     age  sex  height_in  start_weight  end_weight  weight_diff   score  \
# 0  22.0    0       75.0         290.0       185.0        105.0   246.0
# 1  27.0    1       70.0         355.0       340.0         15.0   576.0
# 2  23.0    1       60.0         260.0       218.0         42.0   210.0
# 3  24.0    1       63.0         160.0       135.0         25.0     1.0
# 4  48.0    1       66.0         326.0       180.0        146.0  3163.0
#
#    num_comments  month  dayofweek  NSFW  num_posts
# 0          10.0    1.0        5.0   0.0        1.0
# 1          31.0    1.0        5.0   0.0       12.0
# 2           5.0    1.0        5.0   0.0        1.0
# 3           1.0    1.0        5.0   0.0        1.0
# 4         144.0    1.0        5.0   0.0       15.0

# %%
pp_duration.head()
# Out:
#     age  sex  height_in  start_weight  end_weight  weight_diff   score  \
# 0  22.0    0       75.0         290.0       185.0        105.0   246.0
# 1  27.0    1       70.0         355.0       340.0         15.0   576.0
# 2  23.0    1       60.0         260.0       218.0         42.0   210.0
# 3  24.0    1       63.0         160.0       135.0         25.0     1.0
# 4  48.0    1       66.0         326.0       180.0        146.0  3163.0
#
#    num_comments  month  dayofweek  NSFW  num_posts  period_months       rate  \
# 0          10.0    1.0        5.0   0.0        1.0           24.0   4.375000
# 1          31.0    1.0        5.0   0.0       12.0            1.0  15.000000
# 2           5.0    1.0        5.0   0.0        1.0           12.0   3.500000
# 3           1.0    1.0        5.0   0.0        1.0            6.0   4.166667
# 4         144.0    1.0        5.0   0.0       15.0          101.0   1.445545
#
#    norm_rate
# 0   0.015086
# 1   0.042254
# 2   0.013462
# 3   0.026042
# 4   0.004434

# %% [markdown]
# ### Functions for regression analysis

# %%
# simple linear regression
def linear_regression(y, df, exclude):
    """Generates a simple linear regression model for the provided dependent variable and each independent variable 
    in the provided dataframe, but not included in the exclude list.  Prints the summary of each model and returns a 
    dataframe containing model information. 
    
    Arguments:
    y -- column name of the dependent variable; provide a string
    df -- Pandas dataframe that contains the data for the dependent and independent variables; provide a df
    exclude --  column name(s) to be excluded from the analysis; provide a list of strings or an empty list if
        there are no columns to exclude
        
    Returns:
    results_df -- Pandas dataframe that contains information about each model generated including the F-statistic, F-statistic 
    p-value, t-test, t-test p-value, and R-squared value.
    """
    exclude_cols = []
    results = {}
    exclude_cols.append(y)
    exclude_cols.extend(exclude)
    print('y =', y)
    print("excluded features:", exclude_cols)
    print("df shape:", df.shape)
    features = [col for col in df.columns if col not in exclude_cols]
    for f in features:
        str1 = "{0} ~ {1}".format(y, f)
        reg_model = sm.OLS.from_formula(str1, df).fit()
        results[f] = [round(reg_model.rsquared, 3), round(reg_model.fvalue, 1), round(reg_model.f_pvalue, 4), 
                     round(reg_model.tvalues[1], 2), round(reg_model.pvalues[1], 4)]
        print('X =', f.upper())
        print(reg_model.summary())
        print('')  
    results_df = pd.DataFrame.from_dict(results, columns=["R-sqr", "F-statistic", "F-stat p-value", 't-test',
                                                          't-test p-value'], orient='index')
    return results_df.sort_values("R-sqr", ascending=False)

# %%
# diagnostic plots for a simple linear regression
def lin_regr_diagnostic_plots(y, x, df):
    """Generates diagnostic plots used to evaluate a simple linear regression model. The plots include a scatter plot 
    of the independent variable vs the dependent variable to evaluate linearity, a scatter plot of the standardized
    residuals vs fitted values to evaluate error variance, and a probability plot to evaluate error normality. 
    
    Arguments:
    y -- column name of the dependent variable; provide a string
    x -- column name of the independent variable; provide a string
    df -- Pandas dataframe that contains the data for the dependent and independent variables; provide a df
        
    Returns:
    None 
    """
    str1 = "{0} ~ {1}".format(y, x)
    reg_model = sm.OLS.from_formula(str1, df).fit()
    fit_values = pd.Series(reg_model.fittedvalues, name="fitted_values")
    residuals = pd.Series(reg_model.resid, name="residuals")
    norm_residuals = pd.Series(reg_model.get_influence().resid_studentized_internal, name="Standardized Residual")
                                                              
    fig = plt.figure(constrained_layout=True, figsize=(8,8))
    gs = fig.add_gridspec(2, 2)
    ax1 = fig.add_subplot(gs[0, 0])
    ax1.set_title("Regression plot")
    sns.regplot(x, y, df, line_kws={'color':'r'}, ci=None, ax=ax1)
    ax2 = fig.add_subplot(gs[1, 0])
    ax2.set_title("Standardized residuals vs Fit plot")
    sns.regplot(fit_values, norm_residuals, line_kws={'color':'r'}, ci=None, ax=ax2)
    ax3 = fig.add_subplot(gs[0:, -1])
    sp.stats.probplot(norm_residuals, plot=ax3, fit=True)
    fig.suptitle('y = {}, x = {}'.format(y, x, df), fontsize=14)
    
    return fig

# %%
# These functions implement the "best subsets" regression procedure

def process_subset(y, feature_set, df):
    """Generates a linear regression model and returns the number of independent variables it contains, the 
    names of the independent variables, the model, and the model's RSS value, R-squared value, and R-squared-adjusted
    value.
    """
    str1 = str(y) + ' ~ ' + ' + '.join(list(feature_set))
    model = sm.OLS.from_formula(str1, df)
    regr = model.fit()
    RSS = ((regr.predict(df[list(feature_set)]) - df[y]) ** 2).sum()
    R_squared = regr.rsquared
    R_squared_adj = regr.rsquared_adj
    return {"num_predictors": len(feature_set), "predictors": feature_set, "RSS": RSS, "rsquared": R_squared, "rsquared_adj": R_squared_adj, "model":regr}

def get_best(y, df, features, k):
    """Generates all possible combinations of independent variables, generates linear regression models using the
    variable combinations and returns those with the highest R-squared-adjusted values.
    """
    results = []
    for combo in itertools.combinations(features, k):
        #print("combo:", combo)
        inv_results = process_subset(y, combo, df)
        #print("results:", inv_results["rsquared_adj"])
        results.append(inv_results)
    models = pd.DataFrame(results)
    best_model = models.nlargest(2, "rsquared_adj")
    #print("Best model", best_model)
    return best_model

def subset_linear_regression(y, df, exclude):
    """Generates regression models using all possible combinations of independent variables, then chooses the models 
    with the highest R-squared-adj values. 
    
    Arguments:
    y -- column name of the dependent variable; provide a string
    df -- Pandas dataframe that contains the data for the dependent and independent variables; provide a df
    exclude --  column name(s) to be excluded from the analysis; provide a list of strings or an empty list if
        there are no columns to exclude
        
    Returns:
    models -- Pandas dataframe that contains information about the two (or one) model(s) with the highest R-squared adj
    value from the independent variable combinations.  For example, if there are 4 independent variables, the function 
    will return the two models with the highest R-squared-adj. value if one, two, and three independent variables are 
    included as well as the single model that contains four predictors. The returned information includes the number of 
    independent variables, the names of the independent variables, the model, and the model's RSS value, 
    R-squared value, and R-squared-adjusted value.
    """
    models = pd.DataFrame(columns=["num_predictors", "predictors", "RSS", "rsquared", "rsquared_adj", "model"])
    exclude_cols = []
    exclude_cols.append(y)
    exclude_cols.extend(exclude)
    features = [f for f in df.columns if f not in exclude_cols]
    for i in range(1, len(features)):
        #print("i:", i)
        models = pd.concat([models, get_best(y, df, features, i)], sort=True)
    return models

# %%
# These functions implement the "forward stepwise" regression procedure

def process_subset_ttest(y, feature_set, df):
    """Generates a linear regression model and returns the t-test p-values for all the included independent variables.
    """
    str1 = str(y) + ' ~ ' + ' + '.join(list(feature_set))
    model = sm.OLS.from_formula(str1, df)
    regr = model.fit()
    summary = regr.summary().tables[1]
    pvals = regr.pvalues
    results_series = pd.Series(pvals)
    #print(results_series)
    return results_series

def process_best_model(y, feature_set, df):
    """Generates a linear regression model and returns the number of independent variables it contains, the 
    names of the independent variables, the model, and the model's RSS value, R-squared value, and R-squared-adjusted
    value.
    """
    str1 = str(y) + ' ~ ' + ' + '.join(list(feature_set))
    model = sm.OLS.from_formula(str1, df)
    regr = model.fit()
    RSS = ((regr.predict(df[list(feature_set)]) - df[y]) ** 2).sum()
    R_squared = regr.rsquared
    R_squared_adj = regr.rsquared_adj
    return {"num_predictors": len(feature_set), "predictors": feature_set, "RSS": RSS, "rsquared": R_squared, "rsquared_adj": R_squared_adj, "model":regr}   

def forward_stepwise(y, predictors, y_and_exclude, df):
    """Takes the existing regression model and adds each remaining independent variable to it one at a time.  Compares
    the t-test p-values of new models and identifies the lowest t-test p-value.  If all variables are below the 
    0.15 signficance level, the included predictors are returned.  If the t-test p-values any of the previously 
    included variables now fall below the 0.15 level, they are removed and the remaining predictors are returned.
    """
    remaining_predictors = [p for p in df.columns if p not in predictors and p not in y_and_exclude]
    #print("remaining predictors: ", remaining_predictors)
    results = []
    for p in remaining_predictors:
        #print("p:", p)
        results.append(process_subset_ttest(y, (predictors + [p]), df)) # results is a list of pd Series
    #print("results:", results)
    low_pvalue = 0.15
    index_of_best_series = False
    new_predictors = []
    count = 0
    for i in range(len(results)):
        #print("i", i)
        #print("last value:", results[i][-1].item())
        current = results[i][-1].item()
        if current < 0.15:
            count =+ 1
            if current < low_pvalue:
                low_pvalue = current
                index_best_series = i
    if count == 0:
        for index, value in results[0][:-1].iteritems():
            #print("count = 0, index:", index, "value:", value)
            if index != "Intercept":
                new_predictors.append(index) 
        return(new_predictors)        
    for index, value in results[index_best_series].iteritems():
        #print("index:", index, "value:", value)
        if index != "Intercept":
            if value < 0.15:
                new_predictors.append(index)
    #print("new_predictors:", new_predictors)
    return(new_predictors) 

def stepwise_linear_regression(y, df, exclude):
    """First, individually evaluates independent variables in a linear regression model. The independent variable with 
    the lowest t-test p-value becomes the starting model.  Then the remainder of the independent variables are 
    individually added to the starting model.  If none have a significant t-test p-value then the process ends, but
    if one or many do, the one with the lowest t-test p-value is retained and a new starting model is established (after 
    it is determined that the original independent variable still has a significant t-test p-value).  This process is 
    repeated until no newly added independent variablies have a significant t-test p-value.  The best model from each 
    step is returned. 
    
    Arguments:
    y -- column name of the dependent variable; provide a string
    df -- Pandas dataframe that contains the data for the dependent and independent variables; provide a df
    exclude --  column name(s) to be excluded from the analysis; provide a list of strings or an empty list if
        there are no columns to exclude
        
    Returns:
    models_step -- Pandas dataframe that contains information about best model identified at each step of the process.
    The returned information includes the number of independent variables, the names of the independent variables, the 
    model, and the model's RSS value, R-squared value, and R-squared-adjusted value.
    """
    y_and_exclude = []
    y_and_exclude.append(y)
    y_and_exclude.extend(exclude)
    dep_var = df.shape[1] - len(y_and_exclude)
    #print(dep_var)
    old_predictors = []
    step = 0
    best_models = []
    new_predictors = forward_stepwise(y, old_predictors, y_and_exclude, df)
    best_predictors = [new_predictors]
    #print("1st comparision:", old_predictors, new_predictors)
    while old_predictors != new_predictors:
        step += 1
        #print("step", step)
        old_predictors = new_predictors
        #print('old_predictors:', old_predictors)
        if len(old_predictors) == dep_var:
            break
        new_predictors = forward_stepwise(y, old_predictors, y_and_exclude, df)
        #print('new_predictors:', new_predictors)
        best_predictors.append(new_predictors)
    #print("best_predictors:", best_predictors)    
    for predictor_list in best_predictors[:-1]:
        #print("predictor_list:", predictor_list)
        if predictor_list[-1] == None:
            pass
        else:
            best_models.append(process_best_model(y, predictor_list, df))    
    models_step = pd.DataFrame(best_models)
    return models_step

# %% [markdown]
# ## Regression analysis

# %% [markdown]
# ### Dependent variable = score
#
# Exclude num_comments since it is another descriptor of post populatrity
#
# Use both the pp_data and pp_duration datasets

# %%
# simple linear regression using pp_data
score = linear_regression("score", pp_data, ['num_comments'])
# Out:
# y = score
# excluded features: ['score', 'num_comments']
# df shape: (20065, 12)
# X = AGE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     144.5
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           3.63e-33
# Time:                        12:37:47   Log-Likelihood:            -1.6974e+05
# No. Observations:               20065   AIC:                         3.395e+05
# Df Residuals:                   20063   BIC:                         3.395e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     48.7659     35.479      1.374      0.169     -20.776     118.308
# age           15.8862      1.322     12.020      0.000      13.296      18.477
# ==============================================================================
# Omnibus:                    20492.231   Durbin-Watson:                   1.376
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1039604.797
# Skew:                           5.225   Prob(JB):                         0.00
# Kurtosis:                      36.679   Cond. No.                         118.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = SEX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     391.3
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           2.91e-86
# Time:                        12:37:47   Log-Likelihood:            -1.6962e+05
# No. Observations:               20065   AIC:                         3.392e+05
# Df Residuals:                   20063   BIC:                         3.393e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    299.0628     11.568     25.851      0.000     276.388     321.738
# sex          317.3571     16.044     19.780      0.000     285.910     348.805
# ==============================================================================
# Omnibus:                    20699.082   Durbin-Watson:                   1.402
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1105450.845
# Skew:                           5.293   Prob(JB):                         0.00
# Kurtosis:                      37.788   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = HEIGHT_IN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     135.4
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           3.38e-31
# Time:                        12:37:47   Log-Likelihood:            -1.6975e+05
# No. Observations:               20065   AIC:                         3.395e+05
# Df Residuals:                   20063   BIC:                         3.395e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2046.7573    136.248     15.022      0.000    1779.701    2313.814
# height_in    -23.2798      2.001    -11.637      0.000     -27.201     -19.359
# ==============================================================================
# Omnibus:                    20675.954   Durbin-Watson:                   1.380
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1086859.800
# Skew:                           5.290   Prob(JB):                         0.00
# Kurtosis:                      37.468   Cond. No.                     1.15e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# X = START_WEIGHT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     388.4
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           1.22e-85
# Time:                        12:37:47   Log-Likelihood:            -1.6962e+05
# No. Observations:               20065   AIC:                         3.393e+05
# Df Residuals:                   20063   BIC:                         3.393e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -40.7371     26.840     -1.518      0.129     -93.346      11.872
# start_weight     2.2513      0.114     19.707      0.000       2.027       2.475
# ==============================================================================
# Omnibus:                    20237.277   Durbin-Watson:                   1.384
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           980954.961
# Skew:                           5.135   Prob(JB):                         0.00
# Kurtosis:                      35.678   Cond. No.                         787.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = END_WEIGHT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4300
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):              0.512
# Time:                        12:37:48   Log-Likelihood:            -1.6982e+05
# No. Observations:               20065   AIC:                         3.396e+05
# Df Residuals:                   20063   BIC:                         3.397e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    443.1013     32.971     13.439      0.000     378.476     507.726
# end_weight     0.1173      0.179      0.656      0.512      -0.233       0.468
# ==============================================================================
# Omnibus:                    20615.967   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1064075.687
# Skew:                           5.272   Prob(JB):                         0.00
# Kurtosis:                      37.082   Cond. No.                         751.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = WEIGHT_DIFF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     932.7
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):          2.93e-200
# Time:                        12:37:48   Log-Likelihood:            -1.6936e+05
# No. Observations:               20065   AIC:                         3.387e+05
# Df Residuals:                   20063   BIC:                         3.387e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     218.7721     11.274     19.405      0.000     196.674     240.870
# weight_diff     5.3831      0.176     30.540      0.000       5.038       5.729
# ==============================================================================
# Omnibus:                    20127.860   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           982097.093
# Skew:                           5.083   Prob(JB):                         0.00
# Kurtosis:                      35.731   Cond. No.                         91.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = MONTH
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     6.591
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):             0.0103
# Time:                        12:37:48   Log-Likelihood:            -1.6981e+05
# No. Observations:               20065   AIC:                         3.396e+05
# Df Residuals:                   20063   BIC:                         3.396e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    420.8618     18.671     22.541      0.000     384.265     457.459
# month          6.3684      2.481      2.567      0.010       1.506      11.230
# ==============================================================================
# Omnibus:                    20597.520   Durbin-Watson:                   1.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1059548.444
# Skew:                           5.266   Prob(JB):                         0.00
# Kurtosis:                      37.006   Cond. No.                         17.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = DAYOFWEEK
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.01669
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):              0.897
# Time:                        12:37:48   Log-Likelihood:            -1.6982e+05
# No. Observations:               20065   AIC:                         3.396e+05
# Df Residuals:                   20063   BIC:                         3.397e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    462.5185     14.417     32.082      0.000     434.260     490.777
# dayofweek      0.5207      4.030      0.129      0.897      -7.378       8.420
# ==============================================================================
# Omnibus:                    20626.379   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1067074.537
# Skew:                           5.276   Prob(JB):                         0.00
# Kurtosis:                      37.132   Cond. No.                         6.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = NSFW
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     31.39
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           2.14e-08
# Time:                        12:37:48   Log-Likelihood:            -1.6980e+05
# No. Observations:               20065   AIC:                         3.396e+05
# Df Residuals:                   20063   BIC:                         3.396e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    469.9911      8.156     57.625      0.000     454.004     485.978
# NSFW        -352.0917     62.841     -5.603      0.000    -475.265    -228.918
# ==============================================================================
# Omnibus:                    20622.512   Durbin-Watson:                   1.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1067405.662
# Skew:                           5.274   Prob(JB):                         0.00
# Kurtosis:                      37.139   Cond. No.                         7.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = NUM_POSTS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     461.8
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):          2.71e-101
# Time:                        12:37:48   Log-Likelihood:            -1.6959e+05
# No. Observations:               20065   AIC:                         3.392e+05
# Df Residuals:                   20063   BIC:                         3.392e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    298.3057     11.114     26.840      0.000     276.521     320.090
# num_posts     96.5445      4.493     21.489      0.000      87.739     105.350
# ==============================================================================
# Omnibus:                    20488.436   Durbin-Watson:                   1.402
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1057168.844
# Skew:                           5.215   Prob(JB):                         0.00
# Kurtosis:                      36.996   Cond. No.                         3.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
score
# Out:
#               R-sqr  F-statistic  F-stat p-value  t-test  t-test p-value
# weight_diff   0.044        932.7          0.0000   30.54          0.0000
# num_posts     0.022        461.8          0.0000   21.49          0.0000
# sex           0.019        391.3          0.0000   19.78          0.0000
# start_weight  0.019        388.4          0.0000   19.71          0.0000
# age           0.007        144.5          0.0000   12.02          0.0000
# height_in     0.007        135.4          0.0000  -11.64          0.0000
# NSFW          0.002         31.4          0.0000   -5.60          0.0000
# end_weight    0.000          0.4          0.5120    0.66          0.5120
# month         0.000          6.6          0.0103    2.57          0.0103
# dayofweek     0.000          0.0          0.8972    0.13          0.8972

# %% [markdown]
# None of the variables look like very good predictors for the score of a post even though most have significant p-values...only month and dayofweek are not significant.

# %%
# diagnostic plots for the best feature in pp_data
fig = lin_regr_diagnostic_plots("score", "weight_diff", pp_data)

# %% [markdown]
# Looks like the model created with score predicting weight_diff violates most of the LINE assumptions.  Not a good feature.

# %%
# simple linear regression using pp_duration
score_dur = linear_regression("score", pp_duration, ['norm_rate', 'num_comments'])
# Out:
# y = score
# excluded features: ['score', 'norm_rate', 'num_comments']
# df shape: (12517, 15)
# X = AGE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     76.81
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           2.12e-18
# Time:                        12:37:58   Log-Likelihood:            -1.0560e+05
# No. Observations:               12517   AIC:                         2.112e+05
# Df Residuals:                   12515   BIC:                         2.112e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     85.1327     44.096      1.931      0.054      -1.303     171.568
# age           14.4282      1.646      8.764      0.000      11.201      17.655
# ==============================================================================
# Omnibus:                    12768.977   Durbin-Watson:                   1.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           644515.543
# Skew:                           5.205   Prob(JB):                         0.00
# Kurtosis:                      36.577   Cond. No.                         119.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = SEX
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     279.3
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           5.12e-62
# Time:                        12:37:59   Log-Likelihood:            -1.0550e+05
# No. Observations:               12517   AIC:                         2.110e+05
# Df Residuals:                   12515   BIC:                         2.110e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    296.6521     13.979     21.221      0.000     269.250     324.054
# sex          330.8887     19.801     16.711      0.000     292.076     369.701
# ==============================================================================
# Omnibus:                    12868.473   Durbin-Watson:                   1.386
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           680654.546
# Skew:                           5.253   Prob(JB):                         0.00
# Kurtosis:                      37.564   Cond. No.                         2.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = HEIGHT_IN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     102.9
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           4.44e-24
# Time:                        12:37:59   Log-Likelihood:            -1.0559e+05
# No. Observations:               12517   AIC:                         2.112e+05
# Df Residuals:                   12515   BIC:                         2.112e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2176.9846    169.424     12.849      0.000    1844.887    2509.082
# height_in    -25.1827      2.483    -10.142      0.000     -30.050     -20.316
# ==============================================================================
# Omnibus:                    12849.981   Durbin-Watson:                   1.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           666355.990
# Skew:                           5.250   Prob(JB):                         0.00
# Kurtosis:                      37.168   Cond. No.                     1.16e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# X = START_WEIGHT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     204.3
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           5.60e-46
# Time:                        12:37:59   Log-Likelihood:            -1.0554e+05
# No. Observations:               12517   AIC:                         2.111e+05
# Df Residuals:                   12515   BIC:                         2.111e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.1650     33.375      0.185      0.853     -59.255      71.586
# start_weight     2.0434      0.143     14.293      0.000       1.763       2.324
# ==============================================================================
# Omnibus:                    12629.608   Durbin-Watson:                   1.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           609432.496
# Skew:                           5.128   Prob(JB):                         0.00
# Kurtosis:                      35.609   Cond. No.                         785.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = END_WEIGHT
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     7.296
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):            0.00692
# Time:                        12:37:59   Log-Likelihood:            -1.0564e+05
# No. Observations:               12517   AIC:                         2.113e+05
# Df Residuals:                   12515   BIC:                         2.113e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    572.9806     42.440     13.501      0.000     489.791     656.170
# end_weight    -0.6249      0.231     -2.701      0.007      -1.078      -0.171
# ==============================================================================
# Omnibus:                    12852.859   Durbin-Watson:                   1.355
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           664917.748
# Skew:                           5.253   Prob(JB):                         0.00
# Kurtosis:                      37.125   Cond. No.                         778.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = WEIGHT_DIFF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     620.7
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):          9.08e-134
# Time:                        12:37:59   Log-Likelihood:            -1.0534e+05
# No. Observations:               12517   AIC:                         2.107e+05
# Df Residuals:                   12515   BIC:                         2.107e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     221.7548     13.716     16.168      0.000     194.870     248.640
# weight_diff     5.3749      0.216     24.915      0.000       4.952       5.798
# ==============================================================================
# Omnibus:                    12505.949   Durbin-Watson:                   1.420
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           603176.748
# Skew:                           5.042   Prob(JB):                         0.00
# Kurtosis:                      35.479   Cond. No.                         89.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = MONTH
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.2623
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):              0.609
# Time:                        12:37:59   Log-Likelihood:            -1.0564e+05
# No. Observations:               12517   AIC:                         2.113e+05
# Df Residuals:                   12515   BIC:                         2.113e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    451.0859     22.807     19.779      0.000     406.381     495.791
# month          1.5968      3.118      0.512      0.609      -4.515       7.708
# ==============================================================================
# Omnibus:                    12824.463   Durbin-Watson:                   1.352
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           655226.727
# Skew:                           5.239   Prob(JB):                         0.00
# Kurtosis:                      36.861   Cond. No.                         16.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = DAYOFWEEK
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.605
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):              0.205
# Time:                        12:37:59   Log-Likelihood:            -1.0564e+05
# No. Observations:               12517   AIC:                         2.113e+05
# Df Residuals:                   12515   BIC:                         2.113e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    442.9940     17.760     24.943      0.000     408.181     477.807
# dayofweek      6.3178      4.987      1.267      0.205      -3.457      16.093
# ==============================================================================
# Omnibus:                    12829.324   Durbin-Watson:                   1.353
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           656643.953
# Skew:                           5.241   Prob(JB):                         0.00
# Kurtosis:                      36.899   Cond. No.                         6.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = NSFW
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     21.36
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           3.84e-06
# Time:                        12:37:59   Log-Likelihood:            -1.0563e+05
# No. Observations:               12517   AIC:                         2.113e+05
# Df Residuals:                   12515   BIC:                         2.113e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    467.6488     10.087     46.359      0.000     447.876     487.422
# NSFW        -358.2620     77.511     -4.622      0.000    -510.196    -206.329
# ==============================================================================
# Omnibus:                    12826.396   Durbin-Watson:                   1.356
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           656651.543
# Skew:                           5.239   Prob(JB):                         0.00
# Kurtosis:                      36.901   Cond. No.                         7.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = NUM_POSTS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     114.9
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           1.08e-26
# Time:                        12:37:59   Log-Likelihood:            -1.0558e+05
# No. Observations:               12517   AIC:                         2.112e+05
# Df Residuals:                   12515   BIC:                         2.112e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    359.9067     13.757     26.161      0.000     332.940     386.873
# num_posts     59.6455      5.564     10.719      0.000      48.739      70.552
# ==============================================================================
# Omnibus:                    12849.644   Durbin-Watson:                   1.377
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           666532.686
# Skew:                           5.249   Prob(JB):                         0.00
# Kurtosis:                      37.173   Cond. No.                         3.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = PERIOD_MONTHS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     52.52
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           4.50e-13
# Time:                        12:37:59   Log-Likelihood:            -1.0562e+05
# No. Observations:               12517   AIC:                         2.112e+05
# Df Residuals:                   12515   BIC:                         2.113e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       401.6330     12.970     30.967      0.000     376.211     427.055
# period_months     3.7386      0.516      7.247      0.000       2.727       4.750
# ==============================================================================
# Omnibus:                    12804.911   Durbin-Watson:                   1.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           654212.741
# Skew:                           5.225   Prob(JB):                         0.00
# Kurtosis:                      36.841   Cond. No.                         32.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# X = RATE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  score   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     59.46
# Date:                Thu, 19 Sep 2019   Prob (F-statistic):           1.34e-14
# Time:                        12:38:00   Log-Likelihood:            -1.0561e+05
# No. Observations:               12517   AIC:                         2.112e+05
# Df Residuals:                   12515   BIC:                         2.112e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    385.9231     14.000     27.566      0.000     358.481     413.365
# rate          15.1878      1.970      7.711      0.000      11.327      19.049
# ==============================================================================
# Omnibus:                    12796.420   Durbin-Watson:                   1.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           649033.096
# Skew:                           5.222   Prob(JB):                         0.00
# Kurtosis:                      36.695   Cond. No.                         10.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
score_dur
# Out:
#                R-sqr  F-statistic  F-stat p-value  t-test  t-test p-value
# weight_diff    0.047        620.7          0.0000   24.91          0.0000
# sex            0.022        279.3          0.0000   16.71          0.0000
# start_weight   0.016        204.3          0.0000   14.29          0.0000
# num_posts      0.009        114.9          0.0000   10.72          0.0000
# height_in      0.008        102.9          0.0000  -10.14          0.0000
# age            0.006         76.8          0.0000    8.76          0.0000
# rate           0.005         59.5          0.0000    7.71          0.0000
# period_months  0.004         52.5          0.0000    7.25          0.0000
# NSFW           0.002         21.4          0.0000   -4.62          0.0000
# end_weight     0.001          7.3          0.0069   -2.70          0.0069
# month          0.000          0.3          0.6086    0.51          0.6086
# dayofweek      0.000          1.6          0.2052    1.27          0.2052

# %% [markdown]
# Again, none of the variables look like very good predictors for the score of a post even though most have significant p-values...only month and dayofweek are not significant.

# %%
# diagnostic plots for the best feature in pp_duration
fig = lin_regr_diagnostic_plots("score", "weight_diff", pp_duration)

# %% [markdown]
# Again, looks like the model created with score predicting weight_diff using the pp_duration dataset violates most of the LINE assumptions.  Not a good feature.

# %%
# forward stepwise multiple linear regression for pp_data
# remove features that were not significant in the simple linear regression
score_step = stepwise_linear_regression("score", pp_data, ['num_comments', 'end_weight', 'dayofweek'])

# %%
score_step
# Out:
#    num_predictors                                predictors           RSS  \
# 0               1                             [weight_diff]  2.519795e+10
# 1               2                        [weight_diff, sex]  2.460939e+10
# 2               3             [weight_diff, sex, num_posts]  2.425364e+10
# 3               4       [weight_diff, sex, num_posts, NSFW]  2.421245e+10
# 4               5  [weight_diff, sex, num_posts, NSFW, age]  2.418058e+10
#
#    rsquared  rsquared_adj                                              model
# 0  0.044422      0.044374  <statsmodels.regression.linear_model.Regressio...
# 1  0.066742      0.066649  <statsmodels.regression.linear_model.Regressio...
# 2  0.080233      0.080095  <statsmodels.regression.linear_model.Regressio...
# 3  0.081795      0.081612  <statsmodels.regression.linear_model.Regressio...
# 4  0.083003      0.082775  <statsmodels.regression.linear_model.Regressio...

# %%
# best subsets multiple linear regression for pp_data
# remove features that were not significant in the simple linear regression
score_subset = subset_linear_regression("score", pp_data, ['num_comments', 'end_weight', 'dayofweek'])

# %%
score_subset
# Out:
#              RSS                                              model  \
# 4   2.519795e+10  <statsmodels.regression.linear_model.Regressio...
# 7   2.577603e+10  <statsmodels.regression.linear_model.Regressio...
# 9   2.460939e+10  <statsmodels.regression.linear_model.Regressio...
# 24  2.476112e+10  <statsmodels.regression.linear_model.Regressio...
# 32  2.425364e+10  <statsmodels.regression.linear_model.Regressio...
# 42  2.450861e+10  <statsmodels.regression.linear_model.Regressio...
# 53  2.421245e+10  <statsmodels.regression.linear_model.Regressio...
# 11  2.422156e+10  <statsmodels.regression.linear_model.Regressio...
# 18  2.418058e+10  <statsmodels.regression.linear_model.Regressio...
# 49  2.420987e+10  <statsmodels.regression.linear_model.Regressio...
# 12  2.417812e+10  <statsmodels.regression.linear_model.Regressio...
# 14  2.417853e+10  <statsmodels.regression.linear_model.Regressio...
# 5   2.417608e+10  <statsmodels.regression.linear_model.Regressio...
# 2   2.417791e+10  <statsmodels.regression.linear_model.Regressio...
#
#    num_predictors                                         predictors  \
# 4               1                                     (weight_diff,)
# 7               1                                       (num_posts,)
# 9               2                                 (sex, weight_diff)
# 24              2                           (weight_diff, num_posts)
# 32              3                      (sex, weight_diff, num_posts)
# 42              3                (height_in, weight_diff, num_posts)
# 53              4                (sex, weight_diff, NSFW, num_posts)
# 11              4                 (age, sex, weight_diff, num_posts)
# 18              5           (age, sex, weight_diff, NSFW, num_posts)
# 49              5         (sex, weight_diff, month, NSFW, num_posts)
# 12              6  (age, sex, start_weight, weight_diff, NSFW, nu...
# 14              6    (age, sex, weight_diff, month, NSFW, num_posts)
# 5               7  (age, sex, start_weight, weight_diff, month, N...
# 2               7  (age, sex, height_in, start_weight, weight_dif...
#
#     rsquared  rsquared_adj
# 4   0.044422      0.044374
# 7   0.022499      0.022451
# 9   0.066742      0.066649
# 24  0.060988      0.060894
# 32  0.080233      0.080095
# 42  0.070564      0.070425
# 53  0.081795      0.081612
# 11  0.081449      0.081266
# 18  0.083003      0.082775
# 49  0.081893      0.081664
# 12  0.083096      0.082822
# 14  0.083081      0.082807
# 5   0.083174      0.082854
# 2   0.083105      0.082785

# %% [markdown]
# Trying multiple linear regression with pp_data dataset to understand the score variable:  Weight_diff alone gives a R squared value of 0.04 and that can be doubled to 0.83 by including age, sex, weight_diff, NSFW, and num_posts.  However that model still doesn't explain the variation in the score variable very well and it is complex.

# %%
# forward stepwise multiple linear regression for pp_duration
# remove features that were not significant in the simple linear regression
score_dur_step = stepwise_linear_regression("score", pp_duration, ['num_comments', 'month', 'dayofweek'])

# %%
score_dur_step
# Out:
#    num_predictors                                         predictors  \
# 0               1                                      [weight_diff]
# 1               2                                 [weight_diff, sex]
# 2               3                      [weight_diff, sex, norm_rate]
# 3               4           [weight_diff, sex, norm_rate, num_posts]
# 4               5     [weight_diff, sex, norm_rate, num_posts, NSFW]
# 5               6  [weight_diff, sex, norm_rate, num_posts, NSFW,...
# 6               7  [weight_diff, sex, norm_rate, num_posts, NSFW,...
# 7               8  [weight_diff, sex, norm_rate, num_posts, NSFW,...
# 8               9  [weight_diff, sex, norm_rate, num_posts, NSFW,...
# 9              10  [weight_diff, sex, norm_rate, num_posts, NSFW,...
#
#             RSS  rsquared  rsquared_adj  \
# 0  1.495519e+10  0.047256      0.047180
# 1  1.456082e+10  0.072380      0.072232
# 2  1.448643e+10  0.077120      0.076898
# 3  1.443006e+10  0.080711      0.080417
# 4  1.440228e+10  0.082481      0.082114
# 5  1.438198e+10  0.083773      0.083334
# 6  1.434338e+10  0.086232      0.085721
# 7  1.434338e+10  0.086232      0.085721
# 8  1.432509e+10  0.087398      0.086814
# 9  1.431696e+10  0.087916      0.087260
#
#                                                model
# 0  <statsmodels.regression.linear_model.Regressio...
# 1  <statsmodels.regression.linear_model.Regressio...
# 2  <statsmodels.regression.linear_model.Regressio...
# 3  <statsmodels.regression.linear_model.Regressio...
# 4  <statsmodels.regression.linear_model.Regressio...
# 5  <statsmodels.regression.linear_model.Regressio...
# 6  <statsmodels.regression.linear_model.Regressio...
# 7  <statsmodels.regression.linear_model.Regressio...
# 8  <statsmodels.regression.linear_model.Regressio...
# 9  <statsmodels.regression.linear_model.Regressio...

# %%
# best subsets multiple linear regression for pp_duration
# remove features that were not significant in the simple linear regression
score_dur_subset = subset_linear_regression("score", pp_duration, ['num_comments', 'month', 'dayofweek'])

# %%
score_dur_subset
# Out:
#               RSS                                              model  \
# 5    1.495519e+10  <statsmodels.regression.linear_model.Regressio...
# 1    1.535436e+10  <statsmodels.regression.linear_model.Regressio...
# 13   1.456082e+10  <statsmodels.regression.linear_model.Regressio...
# 21   1.474790e+10  <statsmodels.regression.linear_model.Regressio...
# 70   1.448643e+10  <statsmodels.regression.linear_model.Regressio...
# 67   1.451057e+10  <statsmodels.regression.linear_model.Regressio...
# 190  1.443006e+10  <statsmodels.regression.linear_model.Regressio...
# 193  1.445774e+10  <statsmodels.regression.linear_model.Regressio...
# 323  1.440228e+10  <statsmodels.regression.linear_model.Regressio...
# 329  1.440953e+10  <statsmodels.regression.linear_model.Regressio...
# 340  1.436999e+10  <statsmodels.regression.linear_model.Regressio...
# 365  1.436999e+10  <statsmodels.regression.linear_model.Regressio...
# 283  1.434338e+10  <statsmodels.regression.linear_model.Regressio...
# 278  1.434338e+10  <statsmodels.regression.linear_model.Regressio...
# 68   1.432509e+10  <statsmodels.regression.linear_model.Regressio...
# 79   1.432509e+10  <statsmodels.regression.linear_model.Regressio...
# 33   1.431696e+10  <statsmodels.regression.linear_model.Regressio...
# 34   1.431696e+10  <statsmodels.regression.linear_model.Regressio...
# 8    1.431696e+10  <statsmodels.regression.linear_model.Regressio...
# 5    1.431686e+10  <statsmodels.regression.linear_model.Regressio...
#
#     num_predictors                                         predictors  \
# 5                1                                     (weight_diff,)
# 1                1                                             (sex,)
# 13               2                                 (sex, weight_diff)
# 21               2                           (height_in, weight_diff)
# 70               3                      (sex, weight_diff, norm_rate)
# 67               3                      (sex, weight_diff, num_posts)
# 190              4           (sex, weight_diff, num_posts, norm_rate)
# 193              4                (sex, weight_diff, rate, norm_rate)
# 323              5     (sex, weight_diff, NSFW, num_posts, norm_rate)
# 329              5     (sex, weight_diff, num_posts, rate, norm_rate)
# 340              6  (sex, start_weight, end_weight, num_posts, rat...
# 365              6  (sex, end_weight, weight_diff, num_posts, rate...
# 283              7  (sex, start_weight, weight_diff, NSFW, num_pos...
# 278              7  (sex, start_weight, end_weight, NSFW, num_post...
# 68               8  (age, sex, start_weight, end_weight, NSFW, num...
# 79               8  (age, sex, end_weight, weight_diff, NSFW, num_...
# 33               9  (age, sex, start_weight, end_weight, NSFW, num...
# 34               9  (age, sex, start_weight, weight_diff, NSFW, nu...
# 8               10  (age, sex, start_weight, end_weight, weight_di...
# 5               10  (age, sex, height_in, start_weight, end_weight...
#
#      rsquared  rsquared_adj
# 5    0.047256      0.047180
# 1    0.021826      0.021748
# 13   0.072380      0.072232
# 21   0.060462      0.060312
# 70   0.077120      0.076898
# 67   0.075581      0.075360
# 190  0.080711      0.080417
# 193  0.078947      0.078653
# 323  0.082481      0.082114
# 329  0.082019      0.081652
# 340  0.084537      0.084098
# 365  0.084537      0.084098
# 283  0.086232      0.085721
# 278  0.086232      0.085721
# 68   0.087398      0.086814
# 79   0.087398      0.086814
# 33   0.087916      0.087260
# 34   0.087916      0.087260
# 8    0.087916      0.087260
# 5    0.087923      0.087193

# %% [markdown]
# Trying multiple linear regression with pp_duration dataset to understand the score variable:  Weight_diff alone gives a R squared value of 0.047 and that can be almost doubled to 0.87 by including 8 variablies.  However that model still doesn't explain the variation in the score variable very well and it is complex.
